# %% [markdown]
# # 3.STRINGS

# %% [markdown]
# 1) Count how many vowels are there in a string. Accept the string
# from the user.

# %%
str=input("Enter the string:")

vowels = "aeiouAEIOU"

count = 0

for char in str:
    if char in vowels:
        count += 1
print("Number of vowels in the string:", count)
# Out:
# Enter the string:hello world
# Number of vowels in the string: 3

# %% [markdown]
# 2) Write your own functions (without using built-in functions) to
# convert all characters of a string into lower case/upper case/toggle
# case.

# %%
str=input("Enter the string:")
print("Lower case:",str.lower())
print("Upper case:",str.upper())
print("Toggle case:",str.swapcase())
# Out:
# Enter the string:PyThOn
# Lower case: python
# Upper case: PYTHON
# Toggle case: pYtHoN

# %% [markdown]
# 3) Accept two strings. Check whether one string is there in another
# string.

# %%
str1=input("Enter the string:")
str2=input("Enter the string:")
if str1 in str2:
    print("Yes")
else:
    print("No")
# Out:
# Enter the string:python
# Enter the string:python programming
# Yes

# %% [markdown]
# 4) Write a function that removes one string from another string, if
# present. E.g. Onestring = “abcdef”, removestring = “cd”. The
# finalstring should contain “abef”.

# %%
onestring=input("Enter the string:")
removestring=input("Enter the string:")
finalstring=onestring.replace(removestring,"")
print(finalstring)
# Out:
# Enter the string:abcdef
# Enter the string:cd
# abef
