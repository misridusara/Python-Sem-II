# %% [markdown]
# 1.Write a program that defines a function count_lower_upper() that accepts a string and calculates
# the number of uppercase and lowercase alphabets in it. It should return these values as a dictionary.
# Call this function for some sample string.

# %%
def count_lower_upper(s):
    count = {'uppercase': 0, 'lowercase': 0}
    for char in s:
        if char.isupper():
            count['uppercase'] += 1
        elif char.islower():
            count['lowercase'] += 1
    return count
user_input = input("Enter a string: ")
result = count_lower_upper(user_input)

print("Counts:", result)
# Out:
# Enter a string: Hello WorlD
# Counts: {'uppercase': 3, 'lowercase': 7}

# %% [markdown]
# 2.Write a program that defines a function compute() that calculates the value of n + nn + nnn + nnnn,
# where n is digit received by the function. test the function for digits 4 to 7.

# %%
def compute(n):

    n_str = str(n)
    total = int(n_str) + int(n_str*2) + int(n_str*3) + int(n_str*4)
    return total

for digit in range(4, 8):
    result = compute(digit)
    print("compute(" + str(digit) + ") = " + str(result))
# Out:
# compute(4) = 4936
# compute(5) = 6170
# compute(6) = 7404
# compute(7) = 8638

# %% [markdown]
# Write a program that defines a function create_array() to create and return a 3D array whose
# dimensions are passed to the function. Also initialize each element of this aray to a value passed to
# the function. e.g. create_array(3,4,5,n) where first three arguments are 3D array dimensions and 4th
# value is for initialing each value of the 3D array.

# %%
def create_array(x, y, z, value):

    return [[[value for _ in range(z)] for _ in range(y)] for _ in range(x)]

array_3d = create_array(3, 4, 5, 7)


for i in range(len(array_3d)):
    for j in range(len(array_3d[i])):
        print(array_3d[i][j])
    print()
# Out:
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]
#
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]
#
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]
# [7, 7, 7, 7, 7]

# %% [markdown]
# 4.Write a program that defines a function sum_avg() to accept marks of five subjects and calculates
# total and average. It should return directly both values.

# %%
def sum_avg(marks):

    total = sum(marks)
    average = total / len(marks)
    return total, average

marks = []
for i in range(5):
    m = int(input("Enter marks for subject " + str(i + 1) + ": "))
    marks.append(m)

total, average = sum_avg(marks)

print("Total Marks: " + str(total))
print("Average Marks: " + str(average))
# Out:
# Enter marks for subject 1: 90
# Enter marks for subject 2: 85
# Enter marks for subject 3: 80
# Enter marks for subject 4: 92
# Enter marks for subject 5: 88
# Total Marks: 435
# Average Marks: 87.0

# %% [markdown]
# 5.Pangram is a sentence that uses every letter of the alphabet. Write a program to check whether a
# given string is pangram or not, through a user-defined function ispangram(). Test the function with
# “The quick brown fox jumps over the lazy dog” or “Crazy Fredrick bought many very exquisite opal
# jewels”. Hint: use set() to convert the string into a set of characters present in the string and use <=
# to check whether alphaset is a subset of the given string.

# %%
def ispangram(s):

    s = s.lower()

    alphabet_set = set("abcdefghijklmnopqrstuvwxyz")

    letters_in_s = set(char for char in s if char.isalpha())
    return alphabet_set <= letters_in_s

test1 = "The quick brown fox jumps over the lazy dog"
test2 = "Crazy Fredrick bought many very exquisite opal jewels"
test3 = "This is not a pangram"

print("Test 1:", test1)
print("Is pangram?:", ispangram(test1))
print("Test 2:", test2)
print("Is pangram?:", ispangram(test2))
print("Test 3:", test3)
print("Is pangram?:", ispangram(test3))
# Out:
# Test 1: The quick brown fox jumps over the lazy dog
# Is pangram?: True
# Test 2: Crazy Fredrick bought many very exquisite opal jewels
# Is pangram?: True
# Test 3: This is not a pangram
# Is pangram?: False

# %% [markdown]
# 6.Write a function to create and return a list containing tuples of the form (x,x2,x3) for all x between 1
# and given ending value (both inclusive).

# %%
def generate_tuples(end_value):

    return [(x, x**2, x**3) for x in range(1, end_value + 1)]

end_value = int(input("Enter the ending value: "))
result = generate_tuples(end_value)

print(result)
# Out:
# Enter the ending value: 8
# [(1, 1, 1), (2, 4, 8), (3, 9, 27), (4, 16, 64), (5, 25, 125), (6, 36, 216), (7, 49, 343), (8, 64, 512)]

# %% [markdown]
# 7.A palindrome is a word or phrase that reads the same in both directions. Write a program that
# defines a function ispalindrome() which checks whether a given string is a palindrome or not. Ignore
# spaces and case mismatch while checking for palindrome.

# %%
def ispalindrome(s):

    s = s.replace(" ", "").lower()

    return s == s[::-1]

input_string = input("Enter a string: ")
if ispalindrome(input_string):
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")
# Out:
# Enter a string: Was it a car or a cat I saw
# The string is a palindrome.

# %% [markdown]
# 8.Write a program that defines a function convert() that receives a string containing a sequence of
# whitespace separated words and returns a string after removing all duplicate words and sorting
# them alphanumerically. Hint: use set(), list () , sorted(), join().

# %%
def convert(input_string):

    words = input_string.split()

    unique_words = set(words)

    sorted_words = sorted(unique_words)

    return ' '.join(sorted_words)

input_string = input("Enter a string: ")
result = convert(input_string)
print("Processed string:", result)
# Out:
# Enter a string: zebra lion apple zebra mango
# Processed string: apple lion mango zebra

# %% [markdown]
# 9.Write a program that defines a function count_alpha_digits() that accepts a string and calculates the
# number of alphabets and digits in it. It should return these values as a dictionary.

# %%
def count_alpha_digits(s):
    """Counts the number of alphabets and digits in the given string."""
    count = {'alphabets': 0, 'digits': 0}

    for char in s:
        if char.isalpha():
            count['alphabets'] += 1
        elif char.isdigit():
            count['digits'] += 1

    return count


input_string = input("Enter a string: ")
result = count_alpha_digits(input_string)
print("Character counts:", result)
# Out:
# Enter a string: hello123world456
# Character counts: {'alphabets': 10, 'digits': 6}

# %% [markdown]
# 10.Write a program that defines a function called frequency() which computes the frequency of words
# present in a string passed to it. The frequencies should be returned in sorted order of words in the
# string.

# %%
def frequency(input_string):

    words = input_string.lower().split()
    return sorted((word, words.count(word)) for word in set(words))

input_string = input("Enter a string: ")
result = frequency(input_string)


for word, count in result:
    print(word + ": " + str(count))
# Out:
# Enter a string: apple orange mango apple banana apple mango apple
# apple: 4
# banana: 1
# mango: 2
# orange: 1

# %% [markdown]
# 11.Write a function create_list() that creates and returns a list which is an intersection of two lists
# passed to it.

# %%
def create_list(list1, list2):

    return list(set(list1) & set(list2))

list1 = input("Enter the first list of numbers (comma-separated): ").split(',')
list2 = input("Enter the second list of numbers (comma-separated): ").split(',')

list1 = [int(x) for x in list1]
list2 = [int(x) for x in list2]

result = create_list(list1, list2)
print("Intersection of the two lists:", result)
# Out:
# Enter the first list of numbers (comma-separated): 1,2,3,4,5,6
# Enter the second list of numbers (comma-separated): 2,3,4
# Intersection of the two lists: [2, 3, 4]

# %% [markdown]
# RECURSIVE FUNCTION

# %% [markdown]
# 1.If a positive integer is entered through the keyword, write a recursive function to obtain the prime
# factors of the number.

# %%
def prime_factors(n, divisor=2):

    if n <= 1:
        return []

    if n % divisor == 0:
        return [divisor] + prime_factors(n // divisor, divisor)


    return prime_factors(n, divisor + 1)

n = int(input("Enter a positive integer: "))
result = prime_factors(n)

print("Prime factors of", n, ":", result)
# Out:
# Enter a positive integer: 56
# Prime factors of 56 : [2, 2, 2, 7]

# %% [markdown]
# 2.A positive integer is entered through the keyboard. Write a function to find its binary equivalent of
# this number.

# %%
def to_binary(n):

    return bin(n)[2:]


n = int(input("Enter a positive integer: "))
binary_equivalent = to_binary(n)
print("Binary equivalent of", n, ":", binary_equivalent)
# Out:
# Enter a positive integer: 10
# Binary equivalent of 10 : 1010

# %% [markdown]
# 3.A string is entered through the keyboard. Write a recursive function that counts the number of
# vowels in this string.

# %%
def count_vowels(s):

    if len(s) == 0:
        return 0

    if s[0].lower() in 'aeiou':
        return 1 + count_vowels(s[1:])

    return count_vowels(s[1:])

input_string = input("Enter a string: ")
vowel_count = count_vowels(input_string)
print("Number of vowels:", vowel_count)
# Out:
# Enter a string: hello world
# Number of vowels: 3

# %% [markdown]
# 4.Write a recursive function that reverses the list of numbers that it receives.

# %%
def reverse_list(nums):

    if len(nums) <= 1:
        return nums

    return reverse_list(nums[1:]) + [nums[0]]

input_string = input("Enter a list of numbers separated by spaces: ")
nums = [int(x) for x in input_string.split()]
reversed_nums = reverse_list(nums)
print("Reversed list:", reversed_nums)
# Out:
# Enter a list of numbers separated by spaces: 10 20 30 40 50
# Reversed list: [50, 40, 30, 20, 10]

# %% [markdown]
# 5.Calculate ab where a and b received through the keyword using recursion.

# %%
def power(a, b):

    if b == 0:
        return 1

    return a * power(a, b - 1)

a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
result = power(a, b)
print(a, "raised to the power", b, "is:", result)
# Out:
# Enter the value of a: 2
# Enter the value of b: 3
# 2 raised to the power 3 is: 8

# %% [markdown]
# 6.A list contains some negative and some positive values. Write a recursive function that sanitizes the
# list by replacing all negative numbers with 0.

# %%
def sanitize_list(lst):

    if len(lst) == 0:
        return []


    if lst[0] < 0:
        return [0] + sanitize_list(lst[1:])
    else:
        return [lst[0]] + sanitize_list(lst[1:])


lst = list(map(int, input("Enter a list of numbers separated by spaces: ").split()))
sanitized_lst = sanitize_list(lst)
print("Sanitized list:", sanitized_lst)
# Out:
# Enter a list of numbers separated by spaces: -1 2 -3 4 -5
# Sanitized list: [0, 2, 0, 4, 0]

# %% [markdown]
# 7.Write a recursive function to obtain average of all numbers present in a given list.

# %%
def sum_list(lst):

    if len(lst) == 0:
        return 0
    return lst[0] + sum_list(lst[1:])

def average_list(lst):

    if len(lst) == 0:
        return 0
    total = sum_list(lst)
    return total / len(lst)

input_str = input("Enter a list of numbers separated by spaces: ")
lst = [int(x) for x in input_str.split()]
average = average_list(lst)
print("Average of the list:", average)
# Out:
# Enter a list of numbers separated by spaces: 10 20 30 40 50
# Average of the list: 30.0

# %% [markdown]
# 8.Write a recursive function to obtain length of a given string.

# %%
def string_length(s):

    if s == "":
        return 0
    return 1 + string_length(s[1:])

text = input("Enter a string: ")
length = string_length(text)
print("Length of the string:", length)
# Out:
# Enter a string: recursive function
# Length of the string: 18
